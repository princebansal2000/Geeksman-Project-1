# %% [markdown]
# <a href="https://colab.research.google.com/github/princebansal2000/Geeksman-project-1/blob/master/Notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Creating the dataset of Medical Equipment and uploading it on kaggle.

# %% [markdown]
# Importing required libraries

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import pandas as pd
from fastai.vision import *
from fastai.metrics import error_rate
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
img_counter=[]
img_counter.append(10)

# %% [markdown]
# Uploading the csv files of equipments

# %%
from google.colab import files
i=1
while(i<=6):
 uploaded = files.upload()
 i=i+1
# Out:
#      <input type="file" id="files-eabf0c2e-70fa-474e-b0e5-fc300c156f20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eabf0c2e-70fa-474e-b0e5-fc300c156f20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dialyser.csv to dialyser.csv
#      <input type="file" id="files-e5801426-938c-4630-a1e7-7dd9318e095a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5801426-938c-4630-a1e7-7dd9318e095a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Thermometer.csv to Thermometer.csv
# ...

# %% [markdown]
# Making a folder 'my_data' which will save photos of all equipments.

# %%
folder = 'Otoscope'
url_file = 'Otoscope.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)
verify_images(path/folder, delete=True, max_size=500)

# %%
folder = 'Stethoscope'
url_file = 'Stethoscope.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)
verify_images(path/folder, delete=True, max_size=500)

# %%
folder = 'Thermometer'
url_file = 'Thermometer.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)
verify_images(path/folder, delete=True, max_size=500)

# %%
folder = 'dialyser'
url_file = 'dialyser.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)
verify_images(path/folder, delete=True, max_size=500)

# %%
folder = 'endoscope'
url_file = 'endoscope.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)
verify_images(path/folder, delete=True, max_size=500)

# %%
folder = 'enema'
url_file = 'enema.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)
verify_images(path/folder, delete=True, max_size=500)

# %% [markdown]
# Downloading Kaggle

# %%
# !pip install kaggle

# %% [markdown]
# Uploading the kaggle.json file

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-7ca4d0de-2cbe-447b-8dd7-f81401ed6649" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ca4d0de-2cbe-447b-8dd7-f81401ed6649">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %% [markdown]
# Setting Up Credentials.

# %%
cred = pd.read_json("kaggle.json",lines=True)
os.environ['KAGGLE_USERNAME'] = cred.iloc[0][0]
os.environ['KAGGLE_KEY'] = cred.iloc[0][1]

# %% [markdown]
# Mounting the google drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Ziping the my_data to upload it on kaggle

# %%
# !zip -r "dataset.zip" "my_data"
# Out:
#   adding: my_data/ (stored 0%)
#   adding: my_data/endoscope/ (stored 0%)
#   adding: my_data/endoscope/00000264.jpg (deflated 8%)
#   adding: my_data/endoscope/00000129.jpg (deflated 4%)
#   adding: my_data/endoscope/00000306.jpg (deflated 12%)
#   adding: my_data/endoscope/00000176.jpg (deflated 1%)
#   adding: my_data/endoscope/00000137.jpg (deflated 10%)
#   adding: my_data/endoscope/00000208.jpg (deflated 9%)
#   adding: my_data/endoscope/00000101.jpg (deflated 1%)
#   adding: my_data/endoscope/00000057.jpg (deflated 17%)
#   adding: my_data/endoscope/00000317.jpg (deflated 8%)
#   adding: my_data/endoscope/00000295.jpg (deflated 14%)
#   adding: my_data/endoscope/00000112.jpg (deflated 0%)
#   adding: my_data/endoscope/00000261.jpg (deflated 5%)
#   adding: my_data/endoscope/00000142.jpg (deflated 3%)
#   adding: my_data/endoscope/00000202.jpg (deflated 1%)
#   adding: my_data/endoscope/00000207.jpg (deflated 3%)
#   adding: my_data/endoscope/00000023.jpg (deflated 33%)
# ...

# %% [markdown]
# Making a directory/folder in drive

# %%
os.makedirs("/content/drive/My Drive/medical_equipment",exist_ok=True)

# %% [markdown]
# Storing the address of folder so to avoid writing it again and again.

# %%
my_dir="/content/drive/My Drive/medical_equipment"

# %% [markdown]
# Generating the metadata.json file in drive folder. Make sure you upload dataset,zip file in drive folder because that file will only be uploaded on kaggle.

# %%
# !kaggle datasets init -p '/content/drive/My Drive/medical_equipment'
# Out:
# Data package template written to: /content/drive/My Drive/medical_equipment/dataset-metadata.json

# %% [markdown]
# first open the metadat.json file and add title in it and slug.then run below cell and  it will create the database on kaggle on your id and give the link to access it.

# %%
# !kaggle datasets create -p '/content/drive/My Drive/medical_equipment'
# Out:
# Starting upload for file dataset.zip
# ...
# 100% 11.6M/11.6M [00:09<00:00, 1.31MB/s]
# Upload successful: dataset.zip (12MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/princebansal20/medical-equipment
